# %%
import numpy as np
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('./data/target.csv')
df.dates = pd.to_datetime(df.dates)
# let's add a column that it will be used in the legend following this hack: https://github.com/altair-viz/altair/issues/984
df['legend'] = 'Data'
df.head()
# Out:
#        dates  target legend
# 0 2021-12-26    54.0   Data
# 1 2022-01-02   212.0   Data
# 2 2022-01-09   236.0   Data
# 3 2022-01-16   174.0   Data
# 4 2022-01-23   115.0   Data

# %% [markdown]
# To plot this data in Altair it's necessary to have the same name for the predictions of different models (represent by the columns), and one column that indicates for which model the predictions belong ('model' in the case below). If you have a dataset strcuture by column, take look at the pd.melt function (https://pandas.pydata.org/docs/reference/api/pandas.melt.html)

# %%
df_for = pd.read_csv('./data/forecasts.csv')
df_for.dates = pd.to_datetime(df_for.dates)
df_for
# Out:
#          dates         model  predictions       lower        upper
# 0   2021-12-26            RF   224.030000    0.000000   657.151984
# 1   2022-01-02            RF   311.150000    0.000000   926.336532
# 2   2022-01-09            RF   989.630000    0.000000  2139.728589
# 3   2022-01-16            RF  1550.550000  104.709219  2996.390781
# 4   2022-01-23            RF   368.890000    0.000000  2020.111839
# ..         ...           ...          ...         ...          ...
# 315 2023-06-04  DL - cluster   304.602886  158.264750   426.872812
# 316 2023-06-11  DL - cluster   346.068766  160.559812   536.159720
# 317 2023-06-18  DL - cluster   343.693966  191.552979   543.737511
# 318 2023-06-25  DL - cluster   363.179827  180.028784   503.317822
# 319 2023-07-02  DL - cluster   337.557202  179.437870   502.878968
#
# [320 rows x 5 columns]

# %% [markdown]
# Creating the plot in altair:
#
# The plots in altair are a lot of layers concatenated together. Note that except the `data` element, all the others are based on the `base` element, where it's loaded the `df_for` dataset.

# %%
# here is loaded the element that allows the selection by the mouse
highlight = alt.selection_point(on='mouseover', value = 'DL', fields=['model'], nearest=True)

width = 375 # width of the plots

# here is loaded the data points (black)
data = alt.Chart(df).mark_circle(size = 60).encode(
    x='dates:T',
    y='target:Q',
    color=alt.value('black'),
    opacity=alt.Opacity('legend', legend=alt.Legend(title=None)),

    #size = alt.value(3)
    tooltip = 'target:Q'
).properties(
    width=width
)


# here is created the base element for the time series 
base = alt.Chart(df_for, title="Median Forecast of dengue").encode(
   x=alt.X('dates:T').title('Dates'),
    y=alt.Y('predictions:Q').title('New cases'),
    color='model:N'
).add_params(
    highlight
).properties(
    width=width
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_params(
    highlight
)


# here we create the multine plot and use the alt.condition to highlight only one curve
lines = base.mark_line().encode(
    #size=alt.condition(~highlight, alt.value(1), alt.value(3))
    color=alt.condition(highlight, alt.Color('model:N'), alt.value('lightgray')),
    tooltip = ['model:N', 'predictions']
    
)

# here we define the plot of the right figure
timeseries = alt.Chart(df_for, title="Median and 95% confidence interval").mark_line().encode(
    x=alt.X('dates:T').title('Dates'),
    y=alt.Y('predictions:Q').title('New cases'),
    color=alt.Color('model:N'),
).transform_filter(
    highlight # this function transform filter will just filter the element 
    #in hightlight from the column model N of the df_for (defined in the base element)
)

# here we create the area that represent the confidence interval of the predicitions
timeseries_conf = (timeseries.mark_area(
    opacity=0.5,
).encode(
    x='dates:T',
    y='lower:Q',
    y2='upper:Q'
)
.transform_filter(
    highlight
))

# here we concatenate the layers, the + put one layer above the other
# the | put them syde by syde (as columns), and & put them side by side as lines
final = points + lines + data | timeseries + timeseries_conf + data

final
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# We can save this data as html using:

# %%
final.save('./files_html/forecast_dengue.html')

# %%
# Saving as png it's not working with altair 5.0
final.save('./figures/forecast_dengue.png')
# Out:
# ---------------------------------------------------------------------------
# NoMatchingVersions                        Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Saving as png it's not working with altair 5.0
# ----> 2 final.save('./figures/forecast_dengue.png')
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair/vegalite/v5/api.py:1084, in TopLevelMixin.save(self, fp, format, override_data_transformer, scale_factor, vegalite_version, vega_version, vegaembed_version, **kwargs)
#    1082 if override_data_transformer:
#    1083     with data_transformers.disable_max_rows():
# -> 1084         result = save(**kwds)
#    1085 else:
#    1086     result = save(**kwds)
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair/utils/save.py:189, in save(chart, fp, vega_version, vegaembed_version, format, mode, vegalite_version, embed_options, json_kwds, webdriver, scale_factor, engine, inline, **kwargs)
#     182 else:
#     183     # Temporarily turn off any data transformers so that all data is inlined
#     184     # when calling chart.to_dict. This is relevant for vl-convert which cannot access
#     185     # local json files which could be created by a json data transformer. Furthermore,
#     186     # we don't exit the with statement until this function completed due to the issue
#     187     # described at https://github.com/vega/vl-convert/issues/31
#     188     with data_transformers.enable("default"), data_transformers.disable_max_rows():
# --> 189         perform_save()
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair/utils/save.py:152, in save.<locals>.perform_save()
#     150     write_file_or_filename(fp, mimebundle["text/html"], mode="w")
#     151 elif format in ["png", "svg", "pdf", "vega"]:
# --> 152     mimebundle = spec_to_mimebundle(
#     153         spec=spec,
#     154         format=format,
#     155         mode=inner_mode,
#     156         vega_version=vega_version,
#     157         vegalite_version=vegalite_version,
#     158         vegaembed_version=vegaembed_version,
#     159         webdriver=webdriver,
#     160         scale_factor=scale_factor,
#     161         engine=engine,
#     162         **kwargs,
#     163     )
#     164     if format == "png":
#     165         write_file_or_filename(fp, mimebundle[0]["image/png"], mode="wb")
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair/utils/mimebundle.py:60, in spec_to_mimebundle(spec, format, mode, vega_version, vegaembed_version, vegalite_version, engine, **kwargs)
#      57     mode = "vega"
#      59 if format in ["png", "svg", "pdf", "vega"]:
# ---> 60     return _spec_to_mimebundle_with_engine(
#      61         spec, format, mode, engine=engine, **kwargs
#      62     )
#      63 if format == "html":
#      64     html = spec_to_html(
#      65         spec,
#      66         mode=mode,
#    (...)
#      70         **kwargs,
#      71     )
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair/utils/mimebundle.py:155, in _spec_to_mimebundle_with_engine(spec, format, mode, **kwargs)
#     152 elif normalized_engine == "altairsaver":
#     153     import altair_saver
# --> 155     return altair_saver.render(spec, format, mode=mode, **kwargs)
#     156 else:
#     157     # This should be validated above
#     158     # but raise exception for the sake of future development
#     159     raise ValueError(
#     160         "Unexpected normalized_engine {eng!r}".format(eng=normalized_engine)
#     161     )
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair_saver/_core.py:257, in render(chart, fmts, mode, embed_options, method, **kwargs)
#     255     Saver = _select_saver(method, mode=mode, fmt=fmt)
#     256     saver = Saver(spec, mode=mode, embed_options=embed_options, **kwargs)
# --> 257     mimebundle.update(saver.mimebundle(fmt))
#     259 return mimebundle
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair_saver/savers/_saver.py:90, in Saver.mimebundle(self, fmts)
#      82         raise ValueError(
#      83             f"invalid fmt={fmt!r}; must be one of {self.valid_formats[self._mode]}."
#      84         )
#      85     mimetype = fmt_to_mimetype(
#      86         fmt,
#      87         vega_version=self._package_versions["vega"],
#      88         vegalite_version=self._package_versions["vega-lite"],
#      89     )
# ---> 90     bundle[mimetype] = self._serialize(fmt, "mimebundle")
#      91 return bundle
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair_saver/savers/_selenium.py:284, in SeleniumSaver._serialize(self, fmt, content_type)
#     283 def _serialize(self, fmt: str, content_type: str) -> MimebundleContent:
# --> 284     out = self._extract(fmt)
#     285     if fmt == "png":
#     286         assert isinstance(out, str)
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair_saver/savers/_selenium.py:237, in SeleniumSaver._extract(self, fmt)
#     232 driver = self._registry.get(self._webdriver, self._driver_timeout)
#     234 if self._offline:
#     235     js_resources = {
#     236         "vega.js": get_bundled_script("vega", self._package_versions["vega"]),
# --> 237         "vega-lite.js": get_bundled_script(
#     238             "vega-lite", self._package_versions["vega-lite"]
#     239         ),
#     240         "vega-embed.js": get_bundled_script(
#     241             "vega-embed", self._package_versions["vega-embed"]
#     242         ),
#     243     }
#     244     html = HTML_TEMPLATE.format(
#     245         vega_url="/vega.js",
#     246         vegalite_url="/vega-lite.js",
#     247         vegaembed_url="/vega-embed.js",
#     248     )
#     249 else:
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair_viewer/_scripts.py:40, in get_bundled_script(package, version)
#      36 if package not in listing:
#      37     raise ValueError(
#      38         f"package {package!r} not recognized. Available: {list(listing)}"
#      39     )
# ---> 40 version_str = find_version(version, listing[package])
#      41 path = f"scripts/{package}-{version_str}.js"
#      42 content = pkgutil.get_data("altair_viewer", path)
#
# File ~/Documentos/Projects_software/visualization/.venv/lib/python3.11/site-packages/altair_viewer/_utils.py:212, in find_version(version, candidates, strict_micro)
#     210 matches = [c for c in cand if v.matches(c)]
#     211 if not matches:
# --> 212     raise NoMatchingVersions(
#     213         f"No matches for version={version!r} among {candidates}.\n"
#     214         "Often this can be fixed by updating altair_viewer:\n"
#     215         "    pip install -U altair_viewer"
#     216     )
#     217 return str(matches[-1])
#
# NoMatchingVersions: No matches for version='5.15.1' among ['4.0.2', '4.8.1', '4.17.0'].
# Often this can be fixed by updating altair_viewer:
#     pip install -U altair_viewer

# %%
final.save('./files_html/forecast_dengue.json')
